# %% [markdown]
# <a href="https://colab.research.google.com/github/Dentay/Dentay/blob/main/Pandas_Denis_Tayebwa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
Boston= "/content/bostonHousing1978.csv"
df = pd.read_csv(Boston)
df.head()
# Out:
#       RM  LSTAT  PTRATIO  target
# 0  6.575   4.98     15.3    24.0
# 1  6.421   9.14     17.8    21.6
# 2  7.185   4.03     17.8    34.7
# 3  6.998   2.94     18.7    33.4
# 4  7.147   5.33     18.7    36.2

# %%
Rails= "/content/RailsToTrails_National Count Data_week.xlsx"
df_bike = pd.read_excel(Rails)
df_bike.head()
# Out:
#   Timeframe    Week of   2019 counts (31 counters)  \
# 0    Week 1 2020-12-30                      167679
# 1    Week 2 2020-01-06                       82340
# 2    Week 3 2020-01-13                       62315
# 3    Week 4 2020-01-20                       75801
# 4    Week 5 2020-01-27                       75841
#
#     2020 counts (31 counters)  2021 Counts  Change 2019-2020  Unnamed: 6  \
# 0                      183546          NaN          0.094627    1.094627
# 1                       97140          NaN          0.179743  117.974253
# 2                       75782          NaN          0.216112  121.611169
# 3                       83809          NaN          0.105645  110.564504
# 4                       94738          NaN          0.249166  124.916602
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mGalarnyk/Tutorial_Data/master/Pandas/CalIt2.data' , header = None)
df.head()
# Out:
#    0         1         2  3
# 0  7  07/24/05  00:00:00  0
# 1  9  07/24/05  00:00:00  0
# 2  7  07/24/05  00:30:00  1
# 3  9  07/24/05  00:30:00  0
# 4  7  07/24/05  01:00:00  0

# %%
DT_Sales_Projection="/content/sales_predictions_2023.csv"
