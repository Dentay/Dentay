# %% [markdown]
# <a href="https://colab.research.google.com/github/Dentay/Dentay/blob/main/Denis_Tayebwa_Project1_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Mounting Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #**Loading Data**

# %%
sales='/content/drive/MyDrive/StudentFolders16wk24wk/CodingDojo/01-Fundamentals/Week02/Data/sales_predictions_2023.csv'
import pandas as pd
df=pd.read_csv(sales)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# #**Data Cleaning**

# %%
df.shape
# Out:
# (8523, 12)

# %% [markdown]
# - Number of rows & columns
#   - Rows: 8523
#   - Columns: 12

# %%
#identifying the datatypes
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
#tracing and dropping duplicates
duplicated_rows = df.duplicated()
duplicated_rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#identifying missing values
df.isna()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# ...               ...          ...               ...              ...
# 8518            False        False             False            False
# 8519            False        False             False            False
# 8520            False        False             False            False
# 8521            False        False             False            False
# 8522            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
null_sums = df.isna().sum()
null_sums
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# - Item_Weight and Outlet_Size have 1463 and 2410 null values respectively

# %%
#placeholder values for missing values
df_sales_placeholder=df.fillna(value= "MISSING")
df_sales_placeholder
# Out:
#      Item_Identifier Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.3          Low Fat         0.016047
# 1              DRC01        5.92          Regular         0.019278
# 2              FDN15        17.5          Low Fat         0.016760
# 3              FDX07        19.2          Regular         0.000000
# 4              NCD19        8.93          Low Fat         0.000000
# ...              ...         ...              ...              ...
# 8518           FDF22       6.865          Low Fat         0.056783
# 8519           FDS36        8.38          Regular         0.046982
# 8520           NCJ29        10.6          Low Fat         0.035186
# 8521           FDN46        7.21          Regular         0.145221
# 8522           DRG01        14.8          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#confirming no missing values after applying placeholder
df_sales_placeholder.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
string_cols = df.select_dtypes('object').columns
string_cols
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
for col in string_cols:
  print(f"value counts for {col}")
  print(df[col].value_counts())
  print('\n')
# Out:
# value counts for Item_Identifier
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64
#
#
# value counts for Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
#
# value counts for Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
#
# ...

# %%
#slicing numerical columns
df_sliced_cols= df[['Item_Weight' , 'Item_Visibility' , 'Item_MRP' , 'Outlet_Establishment_Year' , 'Item_Outlet_Sales']]
df_sliced_cols
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# ...

# %%
Item_Weight=df.Item_Weight
Item_Visibility=df.Item_Visibility
Item_MRP=df.Item_MRP
Outlet_Establishment_Year=df.Outlet_Establishment_Year
Item_Outlet_Sales=df.Item_Outlet_Sales
import numpy as np

# %%
min(Item_Weight), max(Item_Weight), df.Item_Weight.mean().round(3)
# Out:
# (4.555, 21.35, 12.858)

# %%
min(Item_Visibility), max(Item_Visibility), df.Item_Visibility.mean().round(3)
# Out:
# (0.0, 0.328390948, 0.066)

# %%
min(Item_MRP), max(Item_MRP), df.Item_MRP.mean().round(3)
# Out:
# (31.29, 266.8884, 140.993)

# %%
min(Outlet_Establishment_Year), max(Outlet_Establishment_Year), df.Outlet_Establishment_Year.mean().round()
# Out:
# (1985, 2009, 1998.0)

# %%
min(Item_Outlet_Sales), max(Item_Outlet_Sales), df.Item_Outlet_Sales.mean().round(3)
# Out:
# (33.29, 13086.9648, 2181.289)
